# %%
import numpy as np
g = np.array([[[0,1],[2,3]],[[0,1],[2,3]]])

print(g)
# print(g[1,0])
# Out:
# [[[0 1]
#   [2 3]]
#
#  [[0 1]
#   [2 3]]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       4 print(g)
#       5 # print(g[1,0])
# ----> 6 g = np.append( [[[4,5],[6,7]],[[8,9],[10,11]]])
#
# TypeError: append() missing 1 required positional argument: 'values'

# %%
#boundary conditions
g[0,:] = 0
g[1,:] = 0
g[:,0] = 0
g[:,1] = 100
